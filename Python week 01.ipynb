# %%
print("Aryan Roy")
# Out:
# Aryan Roy

# %%
print("1, 2, 3, 4, 5, 6, 1+5, 1+5i")
# Out:
# 1, 2, 3, 4, 5, 6, 1+5, 1+5i

# %%
print("Hello")
print("World 1")
# Out:
# Hello
# World 1

# %%
print("Hello", end=" ")
print("World 1")
# Out:
# Hello World 1
